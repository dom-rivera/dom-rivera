# %% [markdown]
# <a href="https://colab.research.google.com/github/dom-rivera/dom-rivera/blob/main/Sample_SD_CaluculatorV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sample Standard Deviation Calculator - Using Statistics Package
# - Helllo everyone! Welcome to my simple project in Python. This project is intended to create a "Sample standaard deviation" calculator.
#
# - The skillsets that are covered within the project includes picture web scrapping, creating a list, string concatination, data conversion, and basic statistics.

# %% [markdown]
# # Import Packages and Libraries in Python

# %%
# Import Statistics package in python
import statistics as st
import math as mt

# Import Request Library
import requests

# Import additional libraries
import os
from PIL import Image
from IPython.display import IFrame

# %% [markdown]
# # Web Scrapping
# - This section is intended to print the formula for the "sample standard deviation". The picture consist of both the "sample and the population standard deviation".
#
# ## Note: The project is specific in computing "sample standard deviation only".

# %%
# Import URL in Python.
Url = 'https://d138zd1ktt9iqe.cloudfront.net/media/seo_landing_files/standard-deviation-formula-1626765976.png'
r2 = requests.get(Url)
print('r2')
print(r2.headers)
# Out:
# r2
# {'Content-Type': 'image/png', 'Content-Length': '25839', 'Connection': 'keep-alive', 'Date': 'Sat, 16 Sep 2023 10:23:36 GMT', 'Last-Modified': 'Tue, 20 Jul 2021 07:26:17 GMT', 'ETag': '"daebdca7710ac594e847c1ce9010c369"', 'x-amz-version-id': 'tA0FST1ze1fszEAhJoSWiSSSRJA8y8r_', 'Accept-Ranges': 'bytes', 'Server': 'AmazonS3', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 496b08d183c170955151833f1238305e.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'TPE52-C1', 'X-Amz-Cf-Id': 'w7poPoM05aWMrYX1kE8gAnYfvR2u_03onDskVIh00TRkKWShyTv8hg==', 'Age': '20756'}

# %%
path = os.path.join(os.getcwd(),'standard-deviation-formula-1626765976.png')
path
# Out:
# '/content/standard-deviation-formula-1626765976.png'

# %%
with open(path,'wb') as f:
    f.write(r2.content)

# %%
# Test Run
SD_Formula = Image.open(path)
SD_Formula
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=831x485>

# %%
# Greetings
Greetings = input('Helllo! Welcome to Sample Standard Deviation Calculator. Type YES to proceed ')

# %%
# Enter Data Function
Data = list(map(int, input('Enter Your Data. Note: Put ONE space between your data').split()))
# Out:
# Enter Your Data. Note: Put ONE space between your data12 12 12 12 12 12 12 12 12
# [12, 12, 12, 12, 12, 12, 12, 12, 12]

# %%
# Indicate values as variables.
Number_data = len(Data)
Sum_of_Data = sum(Data)
Mean = st.mean(Data)
SD = st.stdev(Data)
Variance = st.variance(Data)

# %% [markdown]
# # RUN DATA

# %%
# Greetings
Greetings = input('Helllo! Welcome to Sample Standard Deviation Calculator. Type YES to proceed:\n ')

# Enter Data Function
Data = list(map(int, input('\nEnter Your Data. Note: Put a comma between your data: ').split(',')))

print('\nYour data is:')
print(Data)

# Additional functions
Additionals = input('\nWould you like to proceed to compute your sample SD? Type YES:')

Number_data = len(Data)
Sum_of_Data = sum(Data)
Mean = st.mean(Data)
SD = st.stdev(Data)
Variance = st.variance(Data)
print('\nCongratulations!\n ')
print('\nYour N is:'), ()
print(Number_data)
print('\nThe sum of your data is:')
print(Sum_of_Data)
print('\nYour mean is:')
print(Mean)
print('\nYour sample SD is:')
print(SD)
print('\nYour Variance is:')
print(Variance)

print('\nThe formula that we use to compute the sample SD is: ')
SD_Formula
# Out:
# Helllo! Welcome to Sample Standard Deviation Calculator. Type YES to proceed:
#  YES
#
# Enter Your Data. Note: Put a comma between your data: 12,12,12,15,16,17,19
#
# Your data is:
# [12, 12, 12, 15, 16, 17, 19]
#
# Would you like to proceed to compute your sample SD? Type YES:YES
#
# Congratulations!
#
#
# Your N is:
# 7
#
# The sum of your data is:
# 103
#
# Your mean is:
# 14.714285714285714
#
# Your sample SD is:
# 2.811540841738193
#
# Your Variance is:
# 7.904761904761905
#
# The formula that we use to compute the sample SD is:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=831x485>
